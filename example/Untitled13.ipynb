# %%
import ft2
file=r'E:\FENG临摹\RB2009临摹3.xlsx'

ft2.backtesting(file)
# Out:
# ------------------------------
# 首个交易日：	2009.04.02 09:12
# 最后交易日：	2009.12.30 14:58
# 总交易日：	36
# 盈利交易日：	26
# 亏损交易日：	7
# 起始资金：	200,000.00
# 结束资金：	1,201,800.00
# 总收益率：	500.90%
# 年化收益：	3,339.33%
# 最大回撤: 	-12,000.00
# 百分比最大回撤: -2.98%
# 总盈亏：	1,001,800.00
# 日均盈亏：	27,827.78
# 日均收益率：	4.87%
# 收益标准差：	8.20%
# 夏普比率：	9.21
# 收益回撤比：	168.09
