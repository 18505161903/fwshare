# %%
import ft2
ft2.backtesting(r'C:\Users\Administrator\Documents\rb200937.xlsx')
# Out:
# ------------------------------
# 首个交易日：	2019.03.04 13:34
# 最后交易日：	2020.02.21 09:44
# 总交易日：	143
# 盈利交易日：	93
# 亏损交易日：	41
# 胜率：	65.03%
# 起始资金：	10,000.00
# 结束资金：	22,850.00
# 总收益率：	128.50%
# 年化收益：	215.66%
# 最大回撤: 	-330.00
# 百分比最大回撤: -3.15%
# 总盈亏：	12,850.00
# 日均盈亏：	89.86
# 总成交笔数：	143
# 平均利润：	179.72
# 日均收益率：	0.55%
# 收益标准差：	1.28%
# 夏普比率：	6.64
# 收益回撤比：	40.77
# 日均成交笔数：	1.0

# %%
pip install ft2

# %%
import ft2
ft2.txt_tb(r'C:\Users\Administrator\Documents\rb2019.csv',r'C:\Users\Administrator\Documents\2019.csv')
